# %%
import pandas as pd
import numpy as np
from src import soporte_limpieza as sl

# %%
pd.set_option("display.max_columns", None)

# %%
df_2013 = pd.read_csv("../11.Proyecto2_EDA-Ingresos-Publicos-Brasil/datos/datos-2013_limpio.csv", encoding='latin-1')

df_2014 = pd.read_csv("../11.Proyecto2_EDA-Ingresos-Publicos-Brasil/datos/datos-2014_limpio.csv", encoding='latin-1')

df_2015 = pd.read_csv("../11.Proyecto2_EDA-Ingresos-Publicos-Brasil/datos/datos-2015_limpio.csv", encoding='latin-1')

df_2016 = pd.read_csv("../11.Proyecto2_EDA-Ingresos-Publicos-Brasil/datos/datos-2016_limpio.csv", encoding='latin-1')

df_2017 = pd.read_csv("../11.Proyecto2_EDA-Ingresos-Publicos-Brasil/datos/datos-2017_limpio.csv", encoding='latin-1')

df_2018 = pd.read_csv("../11.Proyecto2_EDA-Ingresos-Publicos-Brasil/datos/datos-2018_limpio.csv", encoding='latin-1')

df_2019 = pd.read_csv("../11.Proyecto2_EDA-Ingresos-Publicos-Brasil/datos/datos-2019_limpio.csv", encoding='latin-1')

df_2020 = pd.read_csv("../11.Proyecto2_EDA-Ingresos-Publicos-Brasil/datos/datos-2020_limpio.csv", encoding='latin-1')

df_2021 = pd.read_csv("../11.Proyecto2_EDA-Ingresos-Publicos-Brasil/datos/datos-2021_limpio.csv", encoding='latin-1')

# %%
df = pd.concat([df_2013, df_2014, df_2015, df_2016, df_2017, df_2018, df_2019, df_2020, df_2021], axis= 0)
df.head(2)
# Out:
#      NOMBRE ÓRGANO SUPERIOR  CÓDIGO ÓRGANO  \
# 0  Advocacia-Geral da União          63000
# 1  Advocacia-Geral da União          63000
#
#                                        NOMBRE ÓRGANO  CÓDIGO UNIDAD GESTORA  \
# 0  Advocacia-Geral da União - Unidades com víncul...                 110060
# 1  Advocacia-Geral da União - Unidades com víncul...                 110060
#
#                            NOMBRE UNIDAD GESTORA CATEGORÍA ECONÓMICA  \
# 0  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
# 1  COORD. GERAL DE ORC. FIN. E ANAL. CONT. - AGU  Receitas Correntes
#
#               ORIGEN INGRESO                                   TIPO INGRESO  \
# 0  Outras Receitas Correntes  Bens, Direitos e Valores Incorporados ao Patr
# 1  Outras Receitas Correntes    Indenizações, restituições e ressarcimentos
#
#                                          DETALLE  VALOR PREVISTO ACTUALIZADO  \
# 0  REC.DIVIDA ATIVA NAO TRIBUTARIA DE OUTRAS REC                         0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1026299 entries, 0 to 134592
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   NOMBRE ÓRGANO SUPERIOR      1026299 non-null  object
#  1   CÓDIGO ÓRGANO               1026299 non-null  int64
#  2   NOMBRE ÓRGANO               1026299 non-null  object
#  3   CÓDIGO UNIDAD GESTORA       1026299 non-null  int64
#  4   NOMBRE UNIDAD GESTORA       1026299 non-null  object
#  5   CATEGORÍA ECONÓMICA         1026299 non-null  object
#  6   ORIGEN INGRESO              1026299 non-null  object
#  7   TIPO INGRESO                1026299 non-null  object
#  8   DETALLE                     1026299 non-null  object
#  9   VALOR PREVISTO ACTUALIZADO  1026299 non-null  float64
#  10  VALOR LANZADO               1026299 non-null  float64
#  11  VALOR REALIZADO             1026299 non-null  float64
# ...

# %%
df["FECHA LANZAMIENTO"] = pd.to_datetime(df["FECHA LANZAMIENTO"], format="mixed")

# %%
df["AÑO EJERCICIO"] = pd.to_datetime(df["AÑO EJERCICIO"], format= '%Y')

# %%
df["AÑO EJERCICIO"] = df["AÑO EJERCICIO"].dt.year

# %%
df.sample()
# Out:
#        NOMBRE ÓRGANO SUPERIOR  CÓDIGO ÓRGANO  \
# 147738    Ministério da Saúde          36212
#
#                                    NOMBRE ÓRGANO  CÓDIGO UNIDAD GESTORA  \
# 147738  Agência Nacional de Vigilância Sanitária                 253002
#
#                            NOMBRE UNIDAD GESTORA CATEGORÍA ECONÓMICA  \
# 147738  AGENCIA NACIONAL DE VIGILANCIA SANITARIA  Receitas Correntes
#
#              ORIGEN INGRESO                                  TIPO INGRESO  \
# 147738  Receita de Serviços  Serviços Administrativos e Comerciais Gerais
#
#                                             DETALLE  \
# 147738  SERV.ADMINISTRAT.E COMERCIAIS GERAIS-PRINC.
#
#         VALOR PREVISTO ACTUALIZADO  VALOR LANZADO  VALOR REALIZADO  \
# 147738                         0.0            0.0             11.2
#
#         PORCENTAJE REALIZADO FECHA LANZAMIENTO  AÑO EJERCICIO
# 147738                   0.0        2018-11-23           2018

# %%
df.to_csv("../11.Proyecto2_EDA-Ingresos-Publicos-Brasil/datos/datos-unidos.csv", index=False, encoding='latin-1')

# %%
df.to_pickle("../11.Proyecto2_EDA-Ingresos-Publicos-Brasil/datos/datos-unidos.pkl")

# %%
df.sample(2)
# Out:
#              NOMBRE ÓRGANO SUPERIOR  CÓDIGO ÓRGANO  \
# 164662  Ministério das Comunicações          41232
# 110200          Ministério da Saúde          36000
#
#                                             NOMBRE ÓRGANO  \
# 164662  Fundo de Universalização dos Serviços de Telec...
# 110200  Ministério da Saúde - Unidades com vínculo direto
#
#         CÓDIGO UNIDAD GESTORA                       NOMBRE UNIDAD GESTORA  \
# 164662                 413047  FUNDO DE UNIVERS.DOS SERV.TELECOMUNICACOES
# 110200                 250088       SPO-COORD.-GERAL DE ORC.E FINANCAS/MS
#
#        CATEGORÍA ECONÓMICA       ORIGEN INGRESO  \
# 164662  Receitas Correntes  Receita Patrimonial
# 110200  Receitas Correntes  Receita de Serviços
#
#                                          TIPO INGRESO  \
# 164662  Delegação de Serviços Públicos Mediante Conce
# 110200   Serviços Administrativos e Comerciais Gerais
#
#                                               DETALLE  \
# ...

# %%
sl.reporte(df)
# Out:
#                             numero_nulos  porcentaje_nulos  tipo_variables
# NOMBRE ÓRGANO SUPERIOR                 0               0.0          object
# CÓDIGO ÓRGANO                          0               0.0           int64
# NOMBRE ÓRGANO                          0               0.0          object
# CÓDIGO UNIDAD GESTORA                  0               0.0           int64
# NOMBRE UNIDAD GESTORA                  0               0.0          object
# CATEGORÍA ECONÓMICA                    0               0.0          object
# ORIGEN INGRESO                         0               0.0          object
# TIPO INGRESO                           0               0.0          object
# DETALLE                                0               0.0          object
# VALOR PREVISTO ACTUALIZADO             0               0.0         float64
# VALOR LANZADO                          0               0.0         float64
# ...

# %%
df.columns
# Out:
# Index(['NOMBRE ÓRGANO SUPERIOR', 'CÓDIGO ÓRGANO', 'NOMBRE ÓRGANO',
#        'CÓDIGO UNIDAD GESTORA', 'NOMBRE UNIDAD GESTORA', 'CATEGORÍA ECONÓMICA',
#        'ORIGEN INGRESO', 'TIPO INGRESO', 'DETALLE',
#        'VALOR PREVISTO ACTUALIZADO', 'VALOR LANZADO', 'VALOR REALIZADO',
#        'PORCENTAJE REALIZADO', 'FECHA LANZAMIENTO', 'AÑO EJERCICIO'],
#       dtype='object')
